# %% [markdown]
# # OpenCV-Python Tutorials
#
# This is a collection of the official OpenCV-Python tutorials converted into interactive Jupyter notebooks.
#
# You can find original tutorials here: [https://docs.opencv.org/5.0/tutorials/tutorials.html](https://docs.opencv.org/5.0/tutorials/tutorials.html)
#
# You can open contribute to this repository by creating a pull request with your changes here: https://github.com/Alex-PLACET/opencv_tutorials
#
# ## Getting Started
#
# ### Locally
#
# ```bash
# pip install -r requirements.txt
# jupyter lab
# ```
#
# ### On Notebook.link
#
# You have nothing to do, just enjoy the notebooks.
#
# Then open any notebook below and run all cells.

# %%
import cv2 as cv

print("OpenCV", cv.__version__)

# %% [markdown]
# ## 1. Core Operations
#
# - [Basic Ops](py_core/py_basic_ops.ipynb)
# - [Image Arithmetics](py_core/py_image_arithmetics.ipynb)
# - [Optimization](py_core/py_optimization.ipynb)

# %% [markdown]
# ## 2. Image Processing in OpenCV
#
# - [Canny](py_imgproc/py_canny/py_canny.ipynb)
# - [Colorspaces](py_imgproc/py_colorspaces/py_colorspaces.ipynb)
# - [Contour Features](py_imgproc/py_contours/py_contour_features/py_contour_features.ipynb)
# - [Contour Properties](py_imgproc/py_contours/py_contour_properties/py_contour_properties.ipynb)
# - [Contours Begin](py_imgproc/py_contours/py_contours_begin/py_contours_begin.ipynb)
# - [Contours Hierarchy](py_imgproc/py_contours/py_contours_hierarchy/py_contours_hierarchy.ipynb)
# - [Contours More Functions](py_imgproc/py_contours/py_contours_more_functions/py_contours_more_functions.ipynb)
# - [Filtering](py_imgproc/py_filtering/py_filtering.ipynb)
# - [Geometric Transformations](py_imgproc/py_geometric_transformations/py_geometric_transformations.ipynb)
# - [Grabcut](py_imgproc/py_grabcut/py_grabcut.ipynb)
# - [Gradients](py_imgproc/py_gradients/py_gradients.ipynb)
# - [2D Histogram](py_imgproc/py_histograms/py_2d_histogram/py_2d_histogram.ipynb)
# - [Histogram Backprojection](py_imgproc/py_histograms/py_histogram_backprojection/py_histogram_backprojection.ipynb)
# - [Histogram Begins](py_imgproc/py_histograms/py_histogram_begins/py_histogram_begins.ipynb)
# - [Histogram Equalization](py_imgproc/py_histograms/py_histogram_equalization/py_histogram_equalization.ipynb)
# - [Houghcircles](py_imgproc/py_houghcircles/py_houghcircles.ipynb)
# - [Houghlines](py_imgproc/py_houghlines/py_houghlines.ipynb)
# - [Morphological Ops](py_imgproc/py_morphological_ops/py_morphological_ops.ipynb)
# - [Pyramids](py_imgproc/py_pyramids/py_pyramids.ipynb)
# - [Template Matching](py_imgproc/py_template_matching/py_template_matching.ipynb)
# - [Thresholding](py_imgproc/py_thresholding/py_thresholding.ipynb)
# - [Fourier Transform](py_imgproc/py_transforms/py_fourier_transform/py_fourier_transform.ipynb)
# - [Watershed](py_imgproc/py_watershed/py_watershed.ipynb)

# %% [markdown]
# ## 3. Feature Detection & Description
#
# - [Fast](py_features/py_fast/py_fast.ipynb)
# - [Feature Homography](py_features/py_feature_homography/py_feature_homography.ipynb)
# - [Features Harris](py_features/py_features_harris/py_features_harris.ipynb)
# - [Features Meaning](py_features/py_features_meaning/py_features_meaning.ipynb)
# - [Matcher](py_features/py_matcher/py_matcher.ipynb)
# - [Orb](py_features/py_orb/py_orb.ipynb)
# - [Shi Tomasi](py_features/py_shi_tomasi/py_shi_tomasi.ipynb)
# - [Sift Intro](py_features/py_sift_intro/py_sift_intro.ipynb)

# %% [markdown]
# ## 4. Video Analysis
#
# - [Bg Subtraction](py_video/py_bg_subtraction/py_bg_subtraction.ipynb)
# - [Lucas Kanade](py_video/py_lucas_kanade/py_lucas_kanade.ipynb)
# - [Meanshift](py_video/py_meanshift/py_meanshift.ipynb)

# %% [markdown]
# ## 5. Camera Calibration & 3D Reconstruction
#
# - [Calibration](py_calib3d/py_calibration/py_calibration.ipynb)
# - [Depthmap](py_calib3d/py_depthmap/py_depthmap.ipynb)
# - [Epipolar Geometry](py_calib3d/py_epipolar_geometry/py_epipolar_geometry.ipynb)
# - [Pose](py_calib3d/py_pose/py_pose.ipynb)

# %% [markdown]
# ## 6. Machine Learning
#
# - [Kmeans Opencv](py_ml/py_kmeans/py_kmeans_opencv/py_kmeans_opencv.ipynb)
# - [Kmeans Understanding](py_ml/py_kmeans/py_kmeans_understanding/py_kmeans_understanding.ipynb)

# %% [markdown]
# ## 7. Computational Photography
#
# - [Chromatic Aberration](py_photo/py_chromatic_aberration/py_chromatic_aberration.ipynb)
# - [Hdr](py_photo/py_hdr/py_hdr.ipynb)
# - [Inpainting](py_photo/py_inpainting/py_inpainting.ipynb)
# - [Non Local Means](py_photo/py_non_local_means/py_non_local_means.ipynb)
